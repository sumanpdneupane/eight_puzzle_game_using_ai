# %%
# !pip3 install import-ipynb

# %%
import import_ipynb
import eight_puzzle_node as EightPuzzle
import heuristic_algo as IDistance
import dfs as DfsSearch
import bfs as BfsSearch
import gbfs as GreedyBestFirstSearch
import a_star as AstarSearch

# %%
# Initial State: Define the initial state (0 represents the blank tile)
initial_state = [
    [0, 2, 3],
    [4, 1, 7],
    [5, 8, 6]
]

# %%
# Goal State
goal_state = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 0]
]

# %%
# Create an instance of EightPuzzle
puzzle = EightPuzzle.EightPuzzle(initial_state= initial_state, goal_state= goal_state)

# %%
# Solve using DFS
# solve = DfsSearch.DfsSearch(puzzle=puzzle)
# solve.solve()

# Solve using BFS
# solve = BfsSearch.BfsSearch(puzzle=puzzle)
# solve.solve()

# # Solve using Greedy Best first search
# distance: IDistance.IDistance = IDistance.MisplacedTilesDistance()
distance: IDistance.IDistance = IDistance.ManhattanDistance()
solve = GreedyBestFirstSearch.GreedyBestFirstSearch(puzzle= puzzle,distance= distance)
solve.solve()



# Solve using A* and Manhattan
# cost: AstarSearch.Cost = AstarSearch.Cost()
# distance: IDistance.IDistance = IDistance.ManhattanDistance()
# # distance: IDistance.IDistance = IDistance.EuclideanDistance()
# # distance: IDistance.IDistance = IDistance.DiagonalDistance()
# solve = AstarSearch.AstarSearch(puzzle= puzzle, cost= cost, distance= distance)
# solve.solve()
# Out:
# ManhattanDistance
# GreedyBestFirstSearch
# _ 2 3
# 4 1 7
# 5 8 6
# ---------------
# [<Direction.DOWN: 'down'>, <Direction.RIGHT: 'right'>]
# 4 2 3
# _ 1 7
# 5 8 6
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.RIGHT: 'right'>]
# 4 2 3
# 5 1 7
# _ 8 6
# ---------------
# [<Direction.UP: 'up'>, <Direction.RIGHT: 'right'>]
# 4 2 3
# 1 _ 7
# 5 8 6
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>, <Direction.RIGHT: 'right'>]
# 4 2 3
# 1 7 _
# 5 8 6
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>]
# 4 2 3
# 1 7 6
# 5 8 _
# ---------------
# [<Direction.UP: 'up'>, <Direction.LEFT: 'left'>]
# 4 2 3
# 1 7 6
# 5 _ 8
# ---------------
# [<Direction.UP: 'up'>, <Direction.LEFT: 'left'>, <Direction.RIGHT: 'right'>]
# 4 2 3
# 1 _ 6
# 5 7 8
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>, <Direction.RIGHT: 'right'>]
# 4 2 3
# 1 7 6
# _ 5 8
# ---------------
# [<Direction.UP: 'up'>, <Direction.RIGHT: 'right'>]
# 4 _ 3
# 1 2 6
# 5 7 8
# ---------------
# [<Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>, <Direction.RIGHT: 'right'>]
# 4 2 3
# _ 1 6
# 5 7 8
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.RIGHT: 'right'>]
# _ 2 3
# 4 1 6
# 5 7 8
# ---------------
# [<Direction.DOWN: 'down'>, <Direction.RIGHT: 'right'>]
# 4 2 3
# 5 1 6
# _ 7 8
# ---------------
# [<Direction.UP: 'up'>, <Direction.RIGHT: 'right'>]
# 4 2 3
# 5 1 6
# 7 _ 8
# ---------------
# [<Direction.UP: 'up'>, <Direction.LEFT: 'left'>, <Direction.RIGHT: 'right'>]
# 4 2 3
# 5 1 6
# 7 8 _
# ---------------
# [<Direction.UP: 'up'>, <Direction.LEFT: 'left'>]
# 4 2 3
# 5 1 _
# 7 8 6
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>]
# 4 2 3
# 5 _ 6
# 7 1 8
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>, <Direction.RIGHT: 'right'>]
# 4 2 3
# _ 5 6
# 7 1 8
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.RIGHT: 'right'>]
# _ 2 3
# 4 5 6
# 7 1 8
# ---------------
# [<Direction.DOWN: 'down'>, <Direction.RIGHT: 'right'>]
# 2 _ 3
# 4 5 6
# 7 1 8
# ---------------
# [<Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>, <Direction.RIGHT: 'right'>]
# 4 2 _
# 5 1 3
# 7 8 6
# ---------------
# [<Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>]
# 4 2 3
# 5 _ 1
# 7 8 6
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>, <Direction.RIGHT: 'right'>]
# 4 2 3
# _ 5 1
# 7 8 6
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.RIGHT: 'right'>]
# _ 2 3
# 4 5 1
# 7 8 6
# ---------------
# [<Direction.DOWN: 'down'>, <Direction.RIGHT: 'right'>]
# 2 _ 3
# 4 5 1
# 7 8 6
# ---------------
# [<Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>, <Direction.RIGHT: 'right'>]
# 4 2 3
# 7 5 6
# _ 1 8
# ---------------
# [<Direction.UP: 'up'>, <Direction.RIGHT: 'right'>]
# 4 2 3
# 7 5 6
# 1 _ 8
# ---------------
# [<Direction.UP: 'up'>, <Direction.LEFT: 'left'>, <Direction.RIGHT: 'right'>]
# 4 2 3
# 7 5 6
# 1 8 _
# ---------------
# [<Direction.UP: 'up'>, <Direction.LEFT: 'left'>]
# 4 2 3
# 7 5 _
# 1 8 6
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>]
# 2 5 3
# 4 _ 6
# 7 1 8
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>, <Direction.RIGHT: 'right'>]
# 2 5 3
# 4 1 6
# 7 _ 8
# ---------------
# [<Direction.UP: 'up'>, <Direction.LEFT: 'left'>, <Direction.RIGHT: 'right'>]
# 2 5 3
# 4 1 6
# 7 8 _
# ---------------
# [<Direction.UP: 'up'>, <Direction.LEFT: 'left'>]
# 2 5 3
# 4 1 _
# 7 8 6
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>]
# 2 3 _
# 4 5 6
# 7 1 8
# ---------------
# [<Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>]
# 4 2 3
# 7 5 1
# _ 8 6
# ---------------
# [<Direction.UP: 'up'>, <Direction.RIGHT: 'right'>]
# 2 5 3
# 4 _ 1
# 7 8 6
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>, <Direction.RIGHT: 'right'>]
# 2 3 _
# 4 5 1
# 7 8 6
# ---------------
# [<Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>]
# 2 3 1
# 4 5 _
# 7 8 6
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>]
# 2 3 1
# 4 5 6
# 7 8 _
# ---------------
# [<Direction.UP: 'up'>, <Direction.LEFT: 'left'>]
# 2 3 1
# 4 5 6
# 7 _ 8
# ---------------
# [<Direction.UP: 'up'>, <Direction.LEFT: 'left'>, <Direction.RIGHT: 'right'>]
# 4 2 3
# 7 _ 6
# 1 5 8
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>, <Direction.RIGHT: 'right'>]
# 4 2 _
# 7 5 3
# 1 8 6
# ---------------
# [<Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>]
# 4 2 3
# 7 _ 5
# 1 8 6
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>, <Direction.RIGHT: 'right'>]
# 2 5 3
# 4 1 6
# _ 7 8
# ---------------
# [<Direction.UP: 'up'>, <Direction.RIGHT: 'right'>]
# 2 5 _
# 4 1 3
# 7 8 6
# ---------------
# [<Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>]
# 2 3 1
# 4 _ 5
# 7 8 6
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>, <Direction.RIGHT: 'right'>]
# 2 3 1
# 4 _ 6
# 7 5 8
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>, <Direction.RIGHT: 'right'>]
# 2 3 1
# 4 5 6
# _ 7 8
# ---------------
# [<Direction.UP: 'up'>, <Direction.RIGHT: 'right'>]
# 4 2 3
# 1 6 _
# 5 7 8
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>]
# 4 2 3
# _ 7 6
# 1 5 8
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.RIGHT: 'right'>]
# _ 2 3
# 4 7 6
# 1 5 8
# ---------------
# [<Direction.DOWN: 'down'>, <Direction.RIGHT: 'right'>]
# 2 _ 3
# 4 1 6
# 5 7 8
# ---------------
# [<Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>, <Direction.RIGHT: 'right'>]
# 2 1 3
# 4 _ 6
# 5 7 8
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>, <Direction.RIGHT: 'right'>]
# 4 _ 3
# 5 2 6
# 7 1 8
# ---------------
# [<Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>, <Direction.RIGHT: 'right'>]
# 4 2 3
# 5 6 _
# 7 1 8
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>]
# 4 _ 2
# 5 1 3
# 7 8 6
# ---------------
# [<Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>, <Direction.RIGHT: 'right'>]
# 4 1 2
# 5 _ 3
# 7 8 6
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>, <Direction.RIGHT: 'right'>]
# 4 1 2
# _ 5 3
# 7 8 6
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.RIGHT: 'right'>]
# _ 1 2
# 4 5 3
# 7 8 6
# ---------------
# [<Direction.DOWN: 'down'>, <Direction.RIGHT: 'right'>]
# 1 _ 2
# 4 5 3
# 7 8 6
# ---------------
# [<Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>, <Direction.RIGHT: 'right'>]
# 1 2 _
# 4 5 3
# 7 8 6
# ---------------
# [<Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>]
# 1 2 3
# 4 5 _
# 7 8 6
# ---------------
# [<Direction.UP: 'up'>, <Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>]
# 1 2 3
# 4 5 6
# 7 8 _
# ---------------
# Goal state reached!
# Solution path: [<Direction.DOWN: 'down'>, <Direction.RIGHT: 'right'>, <Direction.RIGHT: 'right'>, <Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>, <Direction.UP: 'up'>, <Direction.LEFT: 'left'>, <Direction.DOWN: 'down'>, <Direction.RIGHT: 'right'>, <Direction.RIGHT: 'right'>, <Direction.UP: 'up'>, <Direction.UP: 'up'>, <Direction.LEFT: 'left'>, <Direction.DOWN: 'down'>, <Direction.LEFT: 'left'>, <Direction.UP: 'up'>, <Direction.RIGHT: 'right'>, <Direction.RIGHT: 'right'>, <Direction.DOWN: 'down'>, <Direction.DOWN: 'down'>]
